# %%
import cv2
import numpy as np
import pandas as pd

# Load the high-resolution galaxy image
img = cv2.imread('galaxy_image.jpg')
# Convert image to RGB 
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
print(f"Image shape: {img_rgb.shape}")
# Extract RGB channels
r_values = img_rgb[:, :, 0]  # Red channel
g_values = img_rgb[:, :, 1]  # Green channel
b_values = img_rgb[:, :, 2]  # Blue channel
# Flatten the image data into a 2D array and save it to a CSV
pixel_data = img_rgb.reshape(-1, 3)  # Flatten and retain RGB channels
df = pd.DataFrame(pixel_data, columns=['Red', 'Green', 'Blue'])
# Save pixel data to a CSV file
df.to_csv('pixel_data.csv', index=False)
print("Pixel data saved to 'pixel_data.csv'")
# Out:
# Image shape: (800, 1200, 3)
# Pixel data saved to 'pixel_data.csv'

# %%
import matplotlib.pyplot as plt

# Visualize the original image
plt.imshow(img_array)
plt.title("Original Galaxy Image")
plt.axis('off') 
plt.show()
# Plot a heatmap of the Red channel's pixel intensity
plt.imshow(r_values, cmap='Reds')
plt.title("Red Channel Heatmap")
plt.colorbar()
plt.show()
# visualize multiple channels:
fig, ax = plt.subplots(1, 3, figsize=(15, 5))
ax[0].imshow(r_values, cmap='Reds')
ax[0].set_title("Red Channel")
ax[1].imshow(g_values, cmap='Greens')
ax[1].set_title("Green Channel")
ax[2].imshow(b_values, cmap='Blues')
ax[2].set_title("Blue Channel")

plt.show()
